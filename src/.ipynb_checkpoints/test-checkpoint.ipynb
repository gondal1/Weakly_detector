# %%
import matplotlib.pyplot as plt
from scipy.misc import imread, imresize

# %matplotlib inline

img1 = imread('cat_dog1.jpg', mode='RGB')
img1 = imresize(img1, (224, 224))
plt.imshow (img1)
#plt.imshow( img1, cmap=plt.cm.jet, alpha=0.5, interpolation='nearest' )
#prob = sess.run(vgg.probs, feed_dict={vgg.imgs: [img1]})[0]
#preds = (np.argsort(prob)[::-1])[0:5]
#for p in preds:
#    print class_names[p], prob[p]

# %%
from detector_custom import Detector

# %%
#weight_path = '../data/caffe_layers_value.pickle'
weight_path = '/home/gmd8si/Weakly_detector/vgg16CAM.npy'

# %%
n_labels = 1000
detector = Detector(weight_path, n_labels)

# %% [markdown]
# Weights are in the order of (64, 3, 3, 3) i.e. (filters, channels, width, height)... so just remember to take transpose while using tensorflow

# %%
#layer = detector.pretrained_weights['conv1_1']
#feature_map =  detector.visualize_filters(layer[0])
# Then remember to plot the results

# %%
from imagenet_classes import class_names
import tensorflow as tf
tf.reset_default_graph
images_tf = tf.placeholder( tf.float32, [None, 224, 224, 3], name="images")
labels_tf = tf.placeholder( tf.int64, [None], name='labels')

# %%
c1,c2,c3,c4,conv5, conv6, gap, output, prob = detector.inference( images_tf )
classmap = detector.get_classmap( labels_tf, conv6 )
# Out:
# ('check conv_weights', TensorShape([Dimension(3), Dimension(3), Dimension(3), Dimension(64)]))
# ('before bias shape of conv', TensorShape([Dimension(None), Dimension(224), Dimension(224), Dimension(64)]))
# ('check conv_weights', TensorShape([Dimension(3), Dimension(3), Dimension(64), Dimension(64)]))
# ('before bias shape of conv', TensorShape([Dimension(None), Dimension(224), Dimension(224), Dimension(64)]))
# ('check conv_weights', TensorShape([Dimension(3), Dimension(3), Dimension(64), Dimension(128)]))
# ('before bias shape of conv', TensorShape([Dimension(None), Dimension(112), Dimension(112), Dimension(128)]))
# ('check conv_weights', TensorShape([Dimension(3), Dimension(3), Dimension(128), Dimension(128)]))
# ('before bias shape of conv', TensorShape([Dimension(None), Dimension(112), Dimension(112), Dimension(128)]))
# ('check conv_weights', TensorShape([Dimension(3), Dimension(3), Dimension(128), Dimension(256)]))
# ('before bias shape of conv', TensorShape([Dimension(None), Dimension(56), Dimension(56), Dimension(256)]))
# ('check conv_weights', TensorShape([Dimension(3), Dimension(3), Dimension(256), Dimension(256)]))
# ('before bias shape of conv', TensorShape([Dimension(None), Dimension(56), Dimension(56), Dimension(256)]))
# ('check conv_weights', TensorShape([Dimension(3), Dimension(3), Dimension(256), Dimension(256)]))
# ('before bias shape of conv', TensorShape([Dimension(None), Dimension(56), Dimension(56), Dimension(256)]))
# ('check conv_weights', TensorShape([Dimension(3), Dimension(3), Dimension(256), Dimension(512)]))
# ('before bias shape of conv', TensorShape([Dimension(None), Dimension(28), Dimension(28), Dimension(512)]))
# ('check conv_weights', TensorShape([Dimension(3), Dimension(3), Dimension(512), Dimension(512)]))
# ('before bias shape of conv', TensorShape([Dimension(None), Dimension(28), Dimension(28), Dimension(512)]))
# ('check conv_weights', TensorShape([Dimension(3), Dimension(3), Dimension(512), Dimension(512)]))
# ('before bias shape of conv', TensorShape([Dimension(None), Dimension(28), Dimension(28), Dimension(512)]))
# ('check conv_weights', TensorShape([Dimension(3), Dimension(3), Dimension(512), Dimension(512)]))
# ('before bias shape of conv', TensorShape([Dimension(None), Dimension(14), Dimension(14), Dimension(512)]))
# ('check conv_weights', TensorShape([Dimension(3), Dimension(3), Dimension(512), Dimension(512)]))
# ('before bias shape of conv', TensorShape([Dimension(None), Dimension(14), Dimension(14), Dimension(512)]))
# ('check conv_weights', TensorShape([Dimension(3), Dimension(3), Dimension(512), Dimension(512)]))
# ('before bias shape of conv', TensorShape([Dimension(None), Dimension(14), Dimension(14), Dimension(512)]))
# ('fizza', (3, 3, 256, 1024))
# ('bangash', (1024,))
# ('check conv_weights', TensorShape([Dimension(3), Dimension(3), Dimension(256), Dimension(1024)]))
# ('last relu shape', TensorShape([Dimension(None), Dimension(14), Dimension(14), Dimension(512)]))
# ('group shapes', TensorShape([Dimension(None), Dimension(14), Dimension(14), Dimension(256)]))
# ('kernel_shapes', TensorShape([Dimension(3), Dimension(3), Dimension(256), Dimension(512)]))
# ('last conv', TensorShape([Dimension(None), Dimension(14), Dimension(14), Dimension(1024)]))
# ('after bias add - > out', TensorShape([Dimension(None), Dimension(14), Dimension(14), Dimension(1024)]))
# ('gap', TensorShape([Dimension(None), Dimension(1024)]))

# %%
#im_content = tf.read_file('laska.png')
#image = tf.image.decode_jpeg(im_content, channels=3)
#image = tf.cast(image, tf.float32)
#train_image_batch = tf.train.batch(
#    [image], batch_size=1)
import numpy as np
img = np.expand_dims(img1, axis = 0)
#img = tf.cast(img, tf.float32) / 255.
#print (img.shape)
init_op = tf.initialize_all_variables()

# %%
f, axx = plt.subplots(2, sharex=True)

with tf.Session() as sess:
    sess.run(init_op)
    conv6_val, output_val = sess.run([conv6, output], feed_dict={ images_tf: img})
    
    label_predictions = output_val.argmax( axis=1 )
    print 'lab_preds', label_predictions.shape
    preds = (output_val.argsort(axis=1)[:,-3:])[0:5]
    print 'preds_shape', preds.shape
    preds_s = np.squeeze(preds, axis=(0,))
    
    print ('label_preds')
    print class_names[preds_s[-1]]
    print class_names[preds_s[-2]]
    print class_names[preds_s[-3]]
    
    classmap_vals = sess.run(classmap, feed_dict={ labels_tf: label_predictions, conv6: conv6_val})
    
    
classmap_vis = map(lambda x: ((x-x.min())/(x.max()-x.min())), classmap_vals)

cc = np.squeeze(classmap_vals, axis=(0,))
#print (cc.shape)
    #for vis, ori in zip(classmap_vis, current_images):
    #    print l_name
axx[0].imshow(img1)
axx[0].imshow( cc, cmap=plt.cm.jet, alpha=0.5, interpolation='nearest' )
#plt.show()
    
    #acc = (label_predictions == current_labels).sum()
# Out:
# lab_preds (1,)
# preds_shape (1, 3)
# label_preds
# American Staffordshire terrier, Staffordshire terrier, American pit bull terrier, pit bull terrier
# Siamese cat, Siamese
# Great Dane
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-10-0a94b7d23752> in <module>()
#      16     print class_names[preds_s[-3]]
#      17
# ---> 18     classmap_vals = sess.run(classmap, feed_dict={ labels_tf: label_predictions, conv6: conv6_val})
#      19
#      20
#
# /home/gmd8si/tf/lib/python2.7/site-packages/tensorflow/python/client/session.pyc in run(self, fetches, feed_dict, options, run_metadata)
#     715     try:
#     716       result = self._run(None, fetches, feed_dict, options_ptr,
# --> 717                          run_metadata_ptr)
#     718       if run_metadata:
#     719         proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# /home/gmd8si/tf/lib/python2.7/site-packages/tensorflow/python/client/session.pyc in _run(self, handle, fetches, feed_dict, options, run_metadata)
#     892                 'Cannot feed value of shape %r for Tensor %r, '
#     893                 'which has shape %r'
# --> 894                 % (np_val.shape, subfeed_t.name, str(subfeed_t.get_shape())))
#     895           if not self.graph.is_feedable(subfeed_t):
#     896             raise ValueError('Tensor %s may not be fed.' % subfeed_t)
#
# ValueError: Cannot feed value of shape (1,) for Tensor u'labels:0', which has shape '(?, 3)'

# %%
#squeezed_out = np.squeeze(output_val, axis=(0,))
#print (squeezed_out.argsort())
preds = (output_val.argsort(axis=1)[:,-3:])[0:5]
preds = np.squeeze(preds, axis=(0,))
print preds
#print ((output_val.argsort()[:,:-1])[:,:-1])
#print (np.argsort(output_val, axis=1)[::-1])
#print (output_val.argsort()[-3:])[::-1]
# Out:
# [246 284 180]

# %%
    #classmap_answer = sess.run(classmap,feed_dict={labels_tf: current_labels,conv6: conv6_val})

    #classmap_vis = map(lambda x: ((x-x.min())/(x.max()-x.min())), classmap_vals)

    #for vis, ori,ori_path, l_name in zip(classmap_vis, current_images, current_image_paths, current_label_names):
    #    print l_name
    #    plt.imshow( ori )
    #    plt.imshow( vis, cmap=plt.cm.jet, alpha=0.5, interpolation='nearest' )
    #    plt.show()

# %%
with tf.Session() as sess:
    sess.run(init_op)
    #conv6_val, prob = sess.run([conv6, prob],feed_dict={images_tf: img })
    prob = sess.run(prob,feed_dict={images_tf: img })   # This returned value is always a numpy

# %%
print prob.shape
preds = (prob.argmax(axis = 1))[0:5]
#preds = (np.argsort(prob)[:,:,-1])[0:5]
print preds
#for p in preds:
print class_names[preds]
# Out:
# (1, 1000)
# [404]
# airliner
# /home/gmd8si/tf/lib/python2.7/site-packages/ipykernel/__main__.py:6: VisibleDeprecationWarning: converting an array with ndim > 0 to an index will result in an error in the future

# %%
#print output_val
preds = tf.nn.softmax(output_val)
#preds = (np.argsort(prob))[0:5]
print prob
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-25-abe29ac1c7ff> in <module>()
#       1 #print output_val
# ----> 2 preds = tf.nn.softmax(output_val)
#       3 #preds = (np.argsort(prob))[0:5]
#       4 print prob
#
# NameError: name 'output_val' is not defined

# %%
# This is for visualizing weight file
import numpy as np
keys = sorted(detector.pretrained_weights.keys())
for i, k in enumerate(keys):
    print i, k  #, detector.pretrained_weights[k]
#So the weights are alright and are referenced with the layer name IDs
# Out:
# 0 conv1_1
# 1 conv1_2
# 2 conv2_1
# 3 conv2_2
# 4 conv3_1
# 5 conv3_2
# 6 conv3_3
# 7 conv4_1
# 8 conv4_2
# 9 conv4_3
# 10 conv5_1
# 11 conv5_2
# 12 conv5_3
# 13 drop6
# 14 drop7
# 15 fc6
# 16 fc7
# 17 fc8
# 18 pool1
# 19 pool2
# 20 pool3
# 21 pool4
# 22 pool5
# 23 prob
# 24 relu1_1
# 25 relu1_2
# 26 relu2_1
# 27 relu2_2
# 28 relu3_1
# 29 relu3_2
# 30 relu3_3
# 31 relu4_1
# 32 relu4_2
# 33 relu4_3
# 34 relu5_1
# 35 relu5_2
# 36 relu5_3
# 37 relu6
# 38 relu7
